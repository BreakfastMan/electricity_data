# %% [markdown]
# # Analysis of Electricity Use from Sep 7, 2016 to Feb 3, 2019

# %% [markdown]
# ## Inital Data input and analysis

# %%
import numpy as np
import pandas as pd

# %%
print('hello')
# Out:
# hello

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns
sns.set_style('whitegrid')

# %%
# import data
e_data = pd.read_csv('electric_data_2016-09-07_to_2019-01-31.txt')

# %%
# basic info on the data, 21,049 entries
e_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21049 entries, 0 to 21048
# Data columns (total 8 columns):
# TYPE          21049 non-null object
# DATE          21049 non-null object
# START TIME    21049 non-null object
# END TIME      21049 non-null object
# USAGE         21049 non-null float64
# UNITS         21049 non-null object
# COST          21049 non-null object
# NOTES         15 non-null object
# dtypes: float64(1), object(7)
# memory usage: 1.3+ MB

# %%
#looking at the columns of the DataFrame
e_data.head(3)
# Out:
#              TYPE        DATE START TIME END TIME  USAGE UNITS  COST NOTES  \
# 0  Electric usage  2016-09-07      00:00    00:59   0.08   kWh  0.01   NaN
# 1  Electric usage  2016-09-07      01:00    01:59   0.08   kWh  0.01   NaN
# 2  Electric usage  2016-09-07      02:00    02:59   0.06   kWh  0.01   NaN
#
#             timeStamp
# 0 2016-09-07 00:00:00
# 1 2016-09-07 01:00:00
# 2 2016-09-07 02:00:00

# %%
#Create a column for datetime object, will be useful later
e_data['TIME STAMP'] = pd.to_datetime(e_data['DATE'] + ' ' + e_data['START TIME'])
e_data.head(3)
# Out:
#              TYPE        DATE START TIME END TIME  USAGE UNITS   COST NOTES  \
# 0  Electric usage  2016-09-07      00:00    00:59   0.08   kWh  $0.01   NaN
# 1  Electric usage  2016-09-07      01:00    01:59   0.08   kWh  $0.01   NaN
# 2  Electric usage  2016-09-07      02:00    02:59   0.06   kWh  $0.01   NaN
#
#            TIME STAMP
# 0 2016-09-07 00:00:00
# 1 2016-09-07 01:00:00
# 2 2016-09-07 02:00:00

# %%
# Turn COST column from strings to floats
e_data['COST'] = e_data['COST'].apply(lambda cost: float(cost[1:])) #1 because the 1st char is $
e_data.head(3)
# Out:
#              TYPE        DATE START TIME END TIME  USAGE UNITS  COST NOTES  \
# 0  Electric usage  2016-09-07      00:00    00:59   0.08   kWh  0.01   NaN
# 1  Electric usage  2016-09-07      01:00    01:59   0.08   kWh  0.01   NaN
# 2  Electric usage  2016-09-07      02:00    02:59   0.06   kWh  0.01   NaN
#
#            TIME STAMP
# 0 2016-09-07 00:00:00
# 1 2016-09-07 01:00:00
# 2 2016-09-07 02:00:00

# %%
type(e_data['COST'].iloc[0])
# Out:
# numpy.float64

# %%
#distribution plot of hourly electricity use
e_data.hist(bins=80,figsize=(12,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1c8e7f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1dbf3a20>]],
#       dtype=object)

# %%
# mean of hourly electricity use
print(e_data['USAGE'].mean())
# Out:
# 0.22489952016722511

# %%
# max of hourly electricity use
e_data['USAGE'].max()
# Out:
# 2.61

# %% [markdown]
# The max hourly usage of 2.61 is very large compared to the rest of the data. It is possible that there might have been something wrong with the smart meter. I am going to investigate a bit more to see if I can tell if the 2.61 is good data or not.

# %%
#Pull up information about max value
print(e_data[e_data['USAGE']==e_data['USAGE'].max()])
#Check the day of the week. 1 is Tuesday
print(e_data[e_data['USAGE']==e_data['USAGE'].max()].iloc[0]['TIME STAMP'].weekday())
# Out:
#                  TYPE        DATE START TIME END TIME  USAGE UNITS  COST  \
# 18474  Electric usage  2018-10-16      18:00    18:59   2.61   kWh  0.56
#
#       NOTES          TIME STAMP
# 18474   NaN 2018-10-16 18:00:00
# 1

# %%
#plot energy use for the day with the peak hour
y = e_data[e_data['DATE']=='2018-10-16']['USAGE'].values
plt.plot(y)

# %% [markdown]
# This day appears normal. A peak in the morning (electricity for making breakfast and coffee) and then a peak later at night for cooking dinner (electric stove and oven) and then some energy use for the rest of the night (tv and computer use).

# %%
#Look at other 18:00 hours specifically to see if 2.61 is really such an outlier for this time
e_data[e_data['START TIME']=='18:00'].hist(bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1c88d588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d0a9400>]],
#       dtype=object)

# %% [markdown]
# 2.61 is not drastically outside the range of other values. The next closest appears to be 2.3 or so. We must have just been doing a lot of cooking on 10-16-2018.

# %% [markdown]
# ## Create a new DataFrame with the data shown by day

# %%
#set up new data frame with new columns
e_data_day = pd.DataFrame(columns = ['DATE', 'USAGE', 'COST', 'DAY OF WEEK'])
e_data_day.head(3)
# Out:
# Empty DataFrame
# Columns: [DATE, USAGE, COST, DAY OF WEEK]
# Index: []

# %%
#combine data for each day
for i in e_data['DATE'].unique():
    var_cost = e_data[e_data['DATE']==i]['COST'].sum()
    var_usage = e_data[e_data['DATE'] == i]['USAGE'].sum()
    e_data_day = e_data_day.append({'DATE': pd.to_datetime(i), 'USAGE': var_usage, 'COST':var_cost}, ignore_index=True)

# %%
e_data_day.head(3)
# Out:
#         DATE  USAGE  COST  DAY OF WEEK
# 0 2016-09-07   5.58  0.85          NaN
# 1 2016-09-08   2.25  0.35          NaN
# 2 2016-09-09   2.39  0.38          NaN

# %%
#use the datetime object to get the day of the week as a number (0-6)
e_data_day['DAY OF WEEK'] = e_data_day['DATE'].apply(lambda date: date.weekday())
e_data_day.head(3)
# Out:
#         DATE  USAGE  COST  DAY OF WEEK
# 0 2016-09-07   5.58  0.85            2
# 1 2016-09-08   2.25  0.35            3
# 2 2016-09-09   2.39  0.38            4

# %%
#map the number value to the corresponding day of the week name
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
e_data_day['DAY OF WEEK'] = e_data_day['DAY OF WEEK'].map(dmap)
e_data_day.head(3)
# Out:
#         DATE  USAGE  COST DAY OF WEEK
# 0 2016-09-07   5.58  0.85         Wed
# 1 2016-09-08   2.25  0.35         Thu
# 2 2016-09-09   2.39  0.38         Fri

# %%
#total number of days
e_data_day['DATE'].nunique()
# Out:
# 877

# %%
#look at minimum data usage
e_data_day['USAGE'].min()
# Out:
# 0.0

# %%
#0 energy use for the whole day doesn't seem right. Let's look at that day specifically.
e_data_day[e_data_day['USAGE'] == 0]
#Looks like the smart meter wasn't working this day
# Out:
#          DATE  USAGE  COST DAY OF WEEK
# 95 2016-12-11    0.0   0.0         Sun

# %%
# Check the hourly data around that date
e_data[(e_data['DATE']>'2016-12-09') & (e_data['DATE']<'2016-12-13')]

# Appears that the day before and the day after the meter was working properly.
# Out:
#                 TYPE        DATE START TIME END TIME  USAGE UNITS  COST NOTES  \
# 2257  Electric usage  2016-12-10      00:00    00:59   0.07   kWh  0.01   NaN
# 2258  Electric usage  2016-12-10      01:00    01:59   0.08   kWh  0.01   NaN
# 2259  Electric usage  2016-12-10      02:00    02:59   0.07   kWh  0.01   NaN
# 2260  Electric usage  2016-12-10      03:00    03:59   0.06   kWh  0.01   NaN
# 2261  Electric usage  2016-12-10      04:00    04:59   0.06   kWh  0.01   NaN
# 2262  Electric usage  2016-12-10      05:00    05:59   0.08   kWh  0.01   NaN
# 2263  Electric usage  2016-12-10      06:00    06:59   0.08   kWh  0.01   NaN
# 2264  Electric usage  2016-12-10      07:00    07:59   0.08   kWh  0.01   NaN
# 2265  Electric usage  2016-12-10      08:00    08:59   0.06   kWh  0.01   NaN
# 2266  Electric usage  2016-12-10      09:00    09:59   0.06   kWh  0.01   NaN
# 2267  Electric usage  2016-12-10      10:00    10:59   0.08   kWh  0.01   NaN
# 2268  Electric usage  2016-12-10      11:00    11:59   0.15   kWh  0.01   NaN
# 2269  Electric usage  2016-12-10      12:00    12:59   0.21   kWh  0.02   NaN
# 2270  Electric usage  2016-12-10      13:00    13:59   0.21   kWh  0.02   NaN
# 2271  Electric usage  2016-12-10      14:00    14:59   0.20   kWh  0.02   NaN
# 2272  Electric usage  2016-12-10      15:00    15:59   0.19   kWh  0.02   NaN
# 2273  Electric usage  2016-12-10      16:00    16:59   0.17   kWh  0.02   NaN
# 2274  Electric usage  2016-12-10      17:00    17:59   0.10   kWh  0.01   NaN
# 2275  Electric usage  2016-12-10      18:00    18:59   0.08   kWh  0.01   NaN
# 2276  Electric usage  2016-12-10      19:00    19:59   0.08   kWh  0.01   NaN
# 2277  Electric usage  2016-12-10      20:00    20:59   0.18   kWh  0.02   NaN
# 2278  Electric usage  2016-12-10      21:00    21:59   0.10   kWh  0.01   NaN
# 2279  Electric usage  2016-12-10      22:00    22:59   0.14   kWh  0.01   NaN
# 2280  Electric usage  2016-12-10      23:00    23:59   0.13   kWh  0.01   NaN
# 2281  Electric usage  2016-12-11      00:00    00:59   0.00   kWh  0.00   NaN
# 2282  Electric usage  2016-12-11      01:00    01:59   0.00   kWh  0.00   NaN
# 2283  Electric usage  2016-12-11      02:00    02:59   0.00   kWh  0.00   NaN
# 2284  Electric usage  2016-12-11      03:00    03:59   0.00   kWh  0.00   NaN
# 2285  Electric usage  2016-12-11      04:00    04:59   0.00   kWh  0.00   NaN
# 2286  Electric usage  2016-12-11      05:00    05:59   0.00   kWh  0.00   NaN
# ...              ...         ...        ...      ...    ...   ...   ...   ...
# 2299  Electric usage  2016-12-11      18:00    18:59   0.00   kWh  0.00   NaN
# 2300  Electric usage  2016-12-11      19:00    19:59   0.00   kWh  0.00   NaN
# 2301  Electric usage  2016-12-11      20:00    20:59   0.00   kWh  0.00   NaN
# 2302  Electric usage  2016-12-11      21:00    21:59   0.00   kWh  0.00   NaN
# 2303  Electric usage  2016-12-11      22:00    22:59   0.00   kWh  0.00   NaN
# 2304  Electric usage  2016-12-11      23:00    23:59   0.00   kWh  0.00   NaN
# 2305  Electric usage  2016-12-12      00:00    00:59   0.21   kWh  0.02   NaN
# 2306  Electric usage  2016-12-12      01:00    01:59   0.20   kWh  0.02   NaN
# 2307  Electric usage  2016-12-12      02:00    02:59   0.15   kWh  0.01   NaN
# 2308  Electric usage  2016-12-12      03:00    03:59   0.08   kWh  0.01   NaN
# 2309  Electric usage  2016-12-12      04:00    04:59   0.07   kWh  0.01   NaN
# 2310  Electric usage  2016-12-12      05:00    05:59   0.05   kWh  0.00   NaN
# 2311  Electric usage  2016-12-12      06:00    06:59   0.07   kWh  0.01   NaN
# 2312  Electric usage  2016-12-12      07:00    07:59   0.10   kWh  0.01   NaN
# 2313  Electric usage  2016-12-12      08:00    08:59   0.13   kWh  0.01   NaN
# 2314  Electric usage  2016-12-12      09:00    09:59   0.08   kWh  0.01   NaN
# 2315  Electric usage  2016-12-12      10:00    10:59   0.06   kWh  0.01   NaN
# 2316  Electric usage  2016-12-12      11:00    11:59   0.06   kWh  0.01   NaN
# 2317  Electric usage  2016-12-12      12:00    12:59   0.08   kWh  0.01   NaN
# 2318  Electric usage  2016-12-12      13:00    13:59   0.08   kWh  0.01   NaN
# 2319  Electric usage  2016-12-12      14:00    14:59   0.08   kWh  0.01   NaN
# 2320  Electric usage  2016-12-12      15:00    15:59   0.22   kWh  0.02   NaN
# 2321  Electric usage  2016-12-12      16:00    16:59   0.11   kWh  0.01   NaN
# 2322  Electric usage  2016-12-12      17:00    17:59   1.99   kWh  0.19   NaN
# 2323  Electric usage  2016-12-12      18:00    18:59   0.58   kWh  0.06   NaN
# 2324  Electric usage  2016-12-12      19:00    19:59   0.32   kWh  0.03   NaN
# 2325  Electric usage  2016-12-12      20:00    20:59   0.41   kWh  0.04   NaN
# 2326  Electric usage  2016-12-12      21:00    21:59   0.51   kWh  0.05   NaN
# 2327  Electric usage  2016-12-12      22:00    22:59   0.42   kWh  0.04   NaN
# 2328  Electric usage  2016-12-12      23:00    23:59   0.49   kWh  0.05   NaN
#
#               TIME STAMP
# 2257 2016-12-10 00:00:00
# 2258 2016-12-10 01:00:00
# 2259 2016-12-10 02:00:00
# 2260 2016-12-10 03:00:00
# 2261 2016-12-10 04:00:00
# 2262 2016-12-10 05:00:00
# 2263 2016-12-10 06:00:00
# 2264 2016-12-10 07:00:00
# 2265 2016-12-10 08:00:00
# 2266 2016-12-10 09:00:00
# 2267 2016-12-10 10:00:00
# 2268 2016-12-10 11:00:00
# 2269 2016-12-10 12:00:00
# 2270 2016-12-10 13:00:00
# 2271 2016-12-10 14:00:00
# 2272 2016-12-10 15:00:00
# 2273 2016-12-10 16:00:00
# 2274 2016-12-10 17:00:00
# 2275 2016-12-10 18:00:00
# 2276 2016-12-10 19:00:00
# 2277 2016-12-10 20:00:00
# 2278 2016-12-10 21:00:00
# 2279 2016-12-10 22:00:00
# 2280 2016-12-10 23:00:00
# 2281 2016-12-11 00:00:00
# 2282 2016-12-11 01:00:00
# 2283 2016-12-11 02:00:00
# 2284 2016-12-11 03:00:00
# 2285 2016-12-11 04:00:00
# 2286 2016-12-11 05:00:00
# ...                  ...
# 2299 2016-12-11 18:00:00
# 2300 2016-12-11 19:00:00
# 2301 2016-12-11 20:00:00
# 2302 2016-12-11 21:00:00
# 2303 2016-12-11 22:00:00
# 2304 2016-12-11 23:00:00
# 2305 2016-12-12 00:00:00
# 2306 2016-12-12 01:00:00
# 2307 2016-12-12 02:00:00
# 2308 2016-12-12 03:00:00
# 2309 2016-12-12 04:00:00
# 2310 2016-12-12 05:00:00
# 2311 2016-12-12 06:00:00
# 2312 2016-12-12 07:00:00
# 2313 2016-12-12 08:00:00
# 2314 2016-12-12 09:00:00
# 2315 2016-12-12 10:00:00
# 2316 2016-12-12 11:00:00
# 2317 2016-12-12 12:00:00
# 2318 2016-12-12 13:00:00
# 2319 2016-12-12 14:00:00
# 2320 2016-12-12 15:00:00
# 2321 2016-12-12 16:00:00
# 2322 2016-12-12 17:00:00
# 2323 2016-12-12 18:00:00
# 2324 2016-12-12 19:00:00
# 2325 2016-12-12 20:00:00
# 2326 2016-12-12 21:00:00
# 2327 2016-12-12 22:00:00
# 2328 2016-12-12 23:00:00
#
# [72 rows x 9 columns]

# %% [markdown]
# Going to remove data for that day.

# %%
e_data = e_data[e_data['DATE'] != '2016-12-11']
#check to make sure that day was removed
e_data[(e_data['DATE']>'2016-12-09') & (e_data['DATE']<'2016-12-13')]
# Out:
#                 TYPE        DATE START TIME END TIME  USAGE UNITS  COST NOTES  \
# 2257  Electric usage  2016-12-10      00:00    00:59   0.07   kWh  0.01   NaN
# 2258  Electric usage  2016-12-10      01:00    01:59   0.08   kWh  0.01   NaN
# 2259  Electric usage  2016-12-10      02:00    02:59   0.07   kWh  0.01   NaN
# 2260  Electric usage  2016-12-10      03:00    03:59   0.06   kWh  0.01   NaN
# 2261  Electric usage  2016-12-10      04:00    04:59   0.06   kWh  0.01   NaN
# 2262  Electric usage  2016-12-10      05:00    05:59   0.08   kWh  0.01   NaN
# 2263  Electric usage  2016-12-10      06:00    06:59   0.08   kWh  0.01   NaN
# 2264  Electric usage  2016-12-10      07:00    07:59   0.08   kWh  0.01   NaN
# 2265  Electric usage  2016-12-10      08:00    08:59   0.06   kWh  0.01   NaN
# 2266  Electric usage  2016-12-10      09:00    09:59   0.06   kWh  0.01   NaN
# 2267  Electric usage  2016-12-10      10:00    10:59   0.08   kWh  0.01   NaN
# 2268  Electric usage  2016-12-10      11:00    11:59   0.15   kWh  0.01   NaN
# 2269  Electric usage  2016-12-10      12:00    12:59   0.21   kWh  0.02   NaN
# 2270  Electric usage  2016-12-10      13:00    13:59   0.21   kWh  0.02   NaN
# 2271  Electric usage  2016-12-10      14:00    14:59   0.20   kWh  0.02   NaN
# 2272  Electric usage  2016-12-10      15:00    15:59   0.19   kWh  0.02   NaN
# 2273  Electric usage  2016-12-10      16:00    16:59   0.17   kWh  0.02   NaN
# 2274  Electric usage  2016-12-10      17:00    17:59   0.10   kWh  0.01   NaN
# 2275  Electric usage  2016-12-10      18:00    18:59   0.08   kWh  0.01   NaN
# 2276  Electric usage  2016-12-10      19:00    19:59   0.08   kWh  0.01   NaN
# 2277  Electric usage  2016-12-10      20:00    20:59   0.18   kWh  0.02   NaN
# 2278  Electric usage  2016-12-10      21:00    21:59   0.10   kWh  0.01   NaN
# 2279  Electric usage  2016-12-10      22:00    22:59   0.14   kWh  0.01   NaN
# 2280  Electric usage  2016-12-10      23:00    23:59   0.13   kWh  0.01   NaN
# 2305  Electric usage  2016-12-12      00:00    00:59   0.21   kWh  0.02   NaN
# 2306  Electric usage  2016-12-12      01:00    01:59   0.20   kWh  0.02   NaN
# 2307  Electric usage  2016-12-12      02:00    02:59   0.15   kWh  0.01   NaN
# 2308  Electric usage  2016-12-12      03:00    03:59   0.08   kWh  0.01   NaN
# 2309  Electric usage  2016-12-12      04:00    04:59   0.07   kWh  0.01   NaN
# 2310  Electric usage  2016-12-12      05:00    05:59   0.05   kWh  0.00   NaN
# 2311  Electric usage  2016-12-12      06:00    06:59   0.07   kWh  0.01   NaN
# 2312  Electric usage  2016-12-12      07:00    07:59   0.10   kWh  0.01   NaN
# 2313  Electric usage  2016-12-12      08:00    08:59   0.13   kWh  0.01   NaN
# 2314  Electric usage  2016-12-12      09:00    09:59   0.08   kWh  0.01   NaN
# 2315  Electric usage  2016-12-12      10:00    10:59   0.06   kWh  0.01   NaN
# 2316  Electric usage  2016-12-12      11:00    11:59   0.06   kWh  0.01   NaN
# 2317  Electric usage  2016-12-12      12:00    12:59   0.08   kWh  0.01   NaN
# 2318  Electric usage  2016-12-12      13:00    13:59   0.08   kWh  0.01   NaN
# 2319  Electric usage  2016-12-12      14:00    14:59   0.08   kWh  0.01   NaN
# 2320  Electric usage  2016-12-12      15:00    15:59   0.22   kWh  0.02   NaN
# 2321  Electric usage  2016-12-12      16:00    16:59   0.11   kWh  0.01   NaN
# 2322  Electric usage  2016-12-12      17:00    17:59   1.99   kWh  0.19   NaN
# 2323  Electric usage  2016-12-12      18:00    18:59   0.58   kWh  0.06   NaN
# 2324  Electric usage  2016-12-12      19:00    19:59   0.32   kWh  0.03   NaN
# 2325  Electric usage  2016-12-12      20:00    20:59   0.41   kWh  0.04   NaN
# 2326  Electric usage  2016-12-12      21:00    21:59   0.51   kWh  0.05   NaN
# 2327  Electric usage  2016-12-12      22:00    22:59   0.42   kWh  0.04   NaN
# 2328  Electric usage  2016-12-12      23:00    23:59   0.49   kWh  0.05   NaN
#
#               TIME STAMP
# 2257 2016-12-10 00:00:00
# 2258 2016-12-10 01:00:00
# 2259 2016-12-10 02:00:00
# 2260 2016-12-10 03:00:00
# 2261 2016-12-10 04:00:00
# 2262 2016-12-10 05:00:00
# 2263 2016-12-10 06:00:00
# 2264 2016-12-10 07:00:00
# 2265 2016-12-10 08:00:00
# 2266 2016-12-10 09:00:00
# 2267 2016-12-10 10:00:00
# 2268 2016-12-10 11:00:00
# 2269 2016-12-10 12:00:00
# 2270 2016-12-10 13:00:00
# 2271 2016-12-10 14:00:00
# 2272 2016-12-10 15:00:00
# 2273 2016-12-10 16:00:00
# 2274 2016-12-10 17:00:00
# 2275 2016-12-10 18:00:00
# 2276 2016-12-10 19:00:00
# 2277 2016-12-10 20:00:00
# 2278 2016-12-10 21:00:00
# 2279 2016-12-10 22:00:00
# 2280 2016-12-10 23:00:00
# 2305 2016-12-12 00:00:00
# 2306 2016-12-12 01:00:00
# 2307 2016-12-12 02:00:00
# 2308 2016-12-12 03:00:00
# 2309 2016-12-12 04:00:00
# 2310 2016-12-12 05:00:00
# 2311 2016-12-12 06:00:00
# 2312 2016-12-12 07:00:00
# 2313 2016-12-12 08:00:00
# 2314 2016-12-12 09:00:00
# 2315 2016-12-12 10:00:00
# 2316 2016-12-12 11:00:00
# 2317 2016-12-12 12:00:00
# 2318 2016-12-12 13:00:00
# 2319 2016-12-12 14:00:00
# 2320 2016-12-12 15:00:00
# 2321 2016-12-12 16:00:00
# 2322 2016-12-12 17:00:00
# 2323 2016-12-12 18:00:00
# 2324 2016-12-12 19:00:00
# 2325 2016-12-12 20:00:00
# 2326 2016-12-12 21:00:00
# 2327 2016-12-12 22:00:00
# 2328 2016-12-12 23:00:00

# %%
#remove data from date list
e_data_day = e_data_day[e_data_day['DATE'] != '2016-12-11']
#check data
e_data_day[(e_data_day['DATE']>'2016-12-09') & (e_data_day['DATE']<'2016-12-13')]
# Out:
#          DATE  USAGE  COST DAY OF WEEK
# 94 2016-12-10   2.72  0.30         Sat
# 96 2016-12-12   6.55  0.65         Mon

# %%
e_data_day['USAGE'].min()
# Minimum day now is 1.11 kWh which is fine
# Out:
# 1.11

# %%
e_data_day.head(4)
# Out:
#         DATE  USAGE  COST DAY OF WEEK
# 0 2016-09-07   5.58  0.85         Wed
# 1 2016-09-08   2.25  0.35         Thu
# 2 2016-09-09   2.39  0.38         Fri
# 3 2016-09-10   2.09  0.32         Sat

# %%
#Distribution plot of energy usage per day
sns.distplot(e_data_day['USAGE'],bins=100)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# distribution of cost per day
sns.distplot(e_data_day['COST'],bins=100)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(['USAGE'], ['COST'], e_data_day)
# The data is largely fixed between two different slopes. Likely there was a change in $ per kWh at some point.
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Attempt to determine the two different price/kWh rates, and the significance of the dates.
# Going to add a column to that shows the price/kWh rate for each day
from math import log10, floor
e_data_day['$/kWh'] = e_data_day['COST']/e_data_day['USAGE']
e_data_day.head(3)
# Out:
#         DATE  USAGE  COST DAY OF WEEK     $/kWh
# 0 2016-09-07   5.58  0.85         Wed  0.152330
# 1 2016-09-08   2.25  0.35         Thu  0.155556
# 2 2016-09-09   2.39  0.38         Fri  0.158996

# %%
e_data_day['$/kWh'] = e_data_day['$/kWh'].apply(lambda ratio: round(ratio, 3-int(floor(log10(abs(ratio))))-1))
e_data_day.head(10)
# Out:
#         DATE  USAGE  COST DAY OF WEEK  $/kWh
# 0 2016-09-07   5.58  0.85         Wed  0.152
# 1 2016-09-08   2.25  0.35         Thu  0.156
# 2 2016-09-09   2.39  0.38         Fri  0.159
# 3 2016-09-10   2.09  0.32         Sat  0.153
# 4 2016-09-11   5.12  0.81         Sun  0.158
# 5 2016-09-12   3.09  0.44         Mon  0.142
# 6 2016-09-13   4.04  0.65         Tue  0.161
# 7 2016-09-14   5.95  0.93         Wed  0.156
# 8 2016-09-15   4.84  0.74         Thu  0.153
# 9 2016-09-16   3.62  0.56         Fri  0.155

# %%
e_data_day['$/kWh'].mode()
# Out:
# 0    0.213
# dtype: float64

# %%
# Look at distribution of the $/kWh
sns.distplot(e_data_day['$/kWh'],bins=50)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(x='DAY OF WEEK', y='USAGE', data = e_data_day)

# %%
sns.scatterplot(x="DATE", y="USAGE", hue="DAY OF WEEK", data=e_data_day)
plt.xlim([e_data_day['DATE'].min(),  e_data_day['DATE'].max()])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for day in e_data_day['DAY OF WEEK'].unique():
    e_data_day[e_data_day['DAY OF WEEK'] == day]['USAGE'].plot(figsize=(12,4),label=day)
plt.legend()
